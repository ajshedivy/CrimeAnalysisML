# %%
from util.data_util import DataSet

# %%
data_set = 'cleaned_data.zip'
ds = DataSet(data_set)
df = ds.load_data(num_years=2)
df.head()
# Out:
# C:\Users\ajshe\Documents\year4\fall-2021\stat451\CrimeAnalysisML\data\cleaned_data.zip
# downloading: data/2001/data_2001.csv ...
# downloading: data/2002/data_2002.csv ...
#                      Block          Description  Location Description  Arrest  \
# 0                    Block          Description  Location Description  Arrest
# 1  051XX W WASHINGTON BLVD  FIRST DEGREE MURDER                STREET       1
# 2       075XX S HALSTED ST  FIRST DEGREE MURDER            VACANT LOT       0
# 3  059XX W WASHINGTON BLVD  FIRST DEGREE MURDER                 HOUSE       0
# 4       019XX S SAWYER AVE  FIRST DEGREE MURDER                STREET       1
#
#    Domestic  Beat  District  Ward  Community Area  X Coordinate  ...  Cluster  \
# 0  Domestic  Beat  District  Ward  Community Area  X Coordinate  ...  Cluster
# 1         0  1533      15.0  28.0            25.0     1141945.0  ...       20
# 2         0   621       6.0  17.0            71.0     1172275.0  ...       21
# ...

# %%
subset = ['2018', '2019', '2020']
df_subset = ds.load_subset(subset=subset)
df_subset.head()
# Out:
# C:\Users\ajshe\Documents\year4\fall-2021\stat451\CrimeAnalysisML\data\cleaned_data.zip
# downloading: data/2018/data_2018.csv ...
# downloading: data/2019/data_2019.csv ...
# downloading: data/2020/data_2020.csv ...
#                    Block                    Description  \
# 0                  Block                    Description
# 1    016XX W CHICAGO AVE               TELEPHONE THREAT
# 2  068XX S WASHTENAW AVE                         SIMPLE
# 3        040XX W 30TH ST            AGGRAVATED: HANDGUN
# 4        059XX W IOWA ST  SEX ASSLT OF CHILD BY FAM MBR
#
#            Location Description  Arrest  Domestic  Beat  District  Ward  \
# 0          Location Description  Arrest  Domestic  Beat  District  Ward
# 1  GOVERNMENT BUILDING/PROPERTY       1         0  1215      12.0   1.0
# 2      SCHOOL, PUBLIC, BUILDING       0         0   831       8.0  17.0
# 3                      SIDEWALK       1         0  1031      10.0  22.0
# ...

# %%
df_subset['Year'].value_counts()
# Out:
# 2018    262815
# 2019    258133
# 2020    207433
# Year         1
# Name: Year, dtype: int64

# %%
ds1 = DataSet('dne.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24336/2091273386.py in <module>
# ----> 1 ds1 = DataSet('dne.zip')
#
# ~\Documents\year4\fall-2021\stat451\CrimeAnalysisML\util\data_util.py in __init__(self, dataset)
#      22         self.dataset = dataset
#      23         self.data_path = os.path.join(os.getcwd(), 'data', self.dataset)
# ---> 24         self._assert_path()
#      25
#      26     def _assert_path(self):
#
# ~\Documents\year4\fall-2021\stat451\CrimeAnalysisML\util\data_util.py in _assert_path(self)
#      26     def _assert_path(self):
#      27         if not os.path.isfile(self.data_path):
# ---> 28             raise FileNotFoundError(f"{self.data_path} does not exist, make sure it is the correct file \
#      29                 and that it is within the data directory")
#      30
#
# ...
